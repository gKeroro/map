# %%
import os
import json
import pandas as pd
from urllib.request  import urlretrieve
import gzip
import folium

# %%
##透過這個網址可以下載最新的資料
data_url='https://pm25.lass-net.org/data/last-all-airbox.json.gz'
##開始下載資料 後面是放存的路徑
urlretrieve(data_url,r'D:\pm2.5\last-all-airbox.json.gz')
# Out:
# ('D:\\pm2.5\\last-all-airbox.json.gz',
#  <http.client.HTTPMessage at 0x1dd20ff7b48>)

# %%
##自動讀取壓縮檔的json檔
with gzip.open(r'D:\pm2.5\last-all-airbox.json.gz','rb') as f:
    last_data=f.read()
    data = json.loads(last_data)

# %% [markdown]
# #### 欄位說明

# %% [markdown]
# | s_d0 | s_d1 | s_d2 |
# |---| ---| --- |
# | PM2.5 | PM 10 | PM1|
#
# | s_t0 | s_h0 |
# | ---| --- |
# |Temperature | Humidity |

# %%
## 原始資料 可以觀察是在feed裡面
data
# Out:
# {'source': 'last-all-airbox by IIS-NRL',
#  'c_d0_source': 'AS-IISNRL',
#  'num_of_records': 3050,
#  'feeds': [{'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC028604',
#    'SiteAddr': 'N/A',
#    's_d0': 23.0,
#    's_d1': 24.0,
#    's_h0': 100.0,
#    'area': 'taichuang',
#    'gps_lat': 24.10211965,
#    's_t0': 29.75,
#    'gps_lon': 120.7249165,
#    'date': '2020-08-25',
#    'device_id': '08BEAC028604',
#    'name': 'TP_Area_1',
#    'time': '14:39:26',
#    's_d2': 15.0,
#    'timestamp': '2020-08-25T14:39:26Z',
#    'c_d0': 15.49,
#    'c_d0_method': 'GAM/14/10.16'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC02860C',
#    'SiteAddr': 'N/A',
#    's_d0': 20.0,
#    's_d1': 21.0,
#    's_h0': 74.0,
#    'area': 'nantou',
#    'gps_lat': 23.962,
#    's_t0': 27.87,
#    'gps_lon': 120.972,
#    'date': '2020-08-25',
#    'device_id': '08BEAC02860C',
#    'name': '宏仁國中',
#    'time': '14:36:19',
#    's_d2': 12.0,
#    'timestamp': '2020-08-25T14:36:19Z',
#    'c_d0': 11.32,
#    'c_d0_method': 'RFR/14/29.67'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC028622',
#    'SiteAddr': 'N/A',
#    's_d0': 21.0,
#    's_d1': 23.0,
#    's_h0': 72.0,
#    'area': 'nantou',
#    'gps_lat': 23.905,
#    's_t0': 29.61,
#    'gps_lon': 120.689,
#    'date': '2020-08-25',
#    'device_id': '08BEAC028622',
#    'name': '佳音英語-南投分校',
#    'time': '14:41:24',
#    's_d2': 14.0,
#    'timestamp': '2020-08-25T14:41:24Z',
#    'c_d0': 12.42,
#    'c_d0_method': 'RFR/14/0.98'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC028626',
#    'SiteAddr': 'N/A',
#    's_d0': 0.0,
#    's_d1': 0.0,
#    's_h0': 100.0,
#    'area': 'taichuang',
#    'gps_lat': 24.09882084,
#    's_t0': 27.75,
#    'gps_lon': 120.7253515,
#    'date': '2020-08-25',
#    'device_id': '08BEAC028626',
#    'name': 'myPM2.5_26',
#    'time': '14:40:01',
#    's_d2': 0.0,
#    'timestamp': '2020-08-25T14:40:01Z',
#    'c_d0': 0.0,
#    'c_d0_method': 'GAM/14/10.4'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC02862A',
#    'SiteAddr': 'N/A',
#    's_d0': 22.0,
#    's_d1': 24.0,
#    's_h0': 85.0,
#    'area': 'taichuang',
#    'gps_lat': 24.113453,
#    's_t0': 29.11,
#    'gps_lon': 120.662486,
#    'date': '2020-08-25',
#    'device_id': '08BEAC02862A',
#    'name': '中工-新實習大樓新建工程R',
#    'time': '14:37:31',
#    's_d2': 15.0,
#    'timestamp': '2020-08-25T14:37:31Z',
#    'c_d0': 14.4,
#    'c_d0_method': 'GAM/14/4.81'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC02863A',
#    'SiteAddr': 'N/A',
#    's_d0': 26.0,
#    's_d1': 29.0,
#    's_h0': 84.0,
#    'area': 'chiayi_county',
#    'gps_lat': 23.5578778,
#    's_t0': 28.36,
#    'gps_lon': 120.4356678,
#    'date': '2020-08-25',
#    'device_id': '08BEAC02863A',
#    'name': 'AI-1001W',
#    'time': '14:40:26',
#    's_d2': 17.0,
#    'timestamp': '2020-08-25T14:40:26Z',
#    'c_d0': 12.62,
#    'c_d0_method': 'RFR/7/10.56'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC02863E',
#    'SiteAddr': 'N/A',
#    's_d0': 22.0,
#    's_d1': 23.0,
#    's_h0': 100.0,
#    'area': 'taichuang',
#    'gps_lat': 24.301565,
#    's_t0': 26.5,
#    'gps_lon': 120.800889,
#    'date': '2020-08-25',
#    'device_id': '08BEAC02863E',
#    'name': '富山預拌混凝土廠1',
#    'time': '14:39:55',
#    's_d2': 15.0,
#    'timestamp': '2020-08-25T14:39:55Z',
#    'c_d0': 9.6,
#    'c_d0_method': 'GAM/7/10.0'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': 'iTribe長樂部落',
#    'SiteAddr': '',
#    's_d0': 6.0,
#    's_d1': 7.0,
#    's_h0': 100.0,
#    'area': 'pingtung',
#    'gps_lat': 22.074,
#    's_t0': 27.75,
#    'gps_lon': 120.826,
#    'date': '2020-08-25',
#    'device_id': '08BEAC028664',
#    'name': 'iTribe長樂部落',
#    'time': '14:38:51',
#    's_d2': 3.0,
#    'timestamp': '2020-08-25T14:38:51Z',
#    'c_d0': 6.0,
#    'c_d0_method': 'RFR/14/13.45'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': 'iTribe下德武部落',
#    'SiteAddr': '',
#    's_d0': 9.0,
#    's_d1': 11.0,
#    's_h0': 81.0,
#    'area': 'hualien',
#    'gps_lat': 23.48,
#    's_t0': 27.62,
#    'gps_lon': 121.404,
#    'date': '2020-08-25',
#    'device_id': '08BEAC028682',
#    'name': 'iTribe下德武部落',
#    'time': '14:40:49',
#    's_d2': 6.0,
#    'timestamp': '2020-08-25T14:40:49Z',
#    'c_d0': 9.0,
#    'c_d0_method': 'GAM/14/58.13'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': 'iTribe馬兒部落',
#    'SiteAddr': '',
#    's_d0': 19.0,
#    's_d1': 20.0,
#    's_h0': 100.0,
#    'area': 'NA',
#    'gps_lat': 22.787,
#    's_t0': 28.11,
#    'gps_lon': 120.63,
#    'date': '2020-08-25',
#    'device_id': '08BEAC028684',
#    'name': 'iTribe馬兒部落',
#    'time': '14:39:15',
#    's_d2': 13.0,
#    'timestamp': '2020-08-25T14:39:15Z',
#    'c_d0': 11.59,
#    'c_d0_method': 'GAM/14/14.81'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '萬華-2',
#    'SiteAddr': 'Wanhua',
#    's_d0': 27.0,
#    's_d1': 29.0,
#    's_h0': 100.0,
#    'area': 'taipei',
#    'gps_lat': 25.046,
#    's_t0': 29.86,
#    'gps_lon': 121.508,
#    'date': '2020-08-25',
#    'device_id': '08BEAC028690',
#    'name': '手動站：萬華站-2（690)',
#    'time': '14:39:26',
#    's_d2': 18.0,
#    'timestamp': '2020-08-25T14:39:26Z',
#    'c_d0': 15.82,
#    'c_d0_method': 'SVR/30/0.11'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC0286AE',
#    'SiteAddr': 'N/A',
#    's_d0': 24.0,
#    's_d1': 26.0,
#    's_h0': 65.0,
#    'area': 'new_taipei',
#    'gps_lat': 25.05349005,
#    's_t0': 32.36,
#    'gps_lon': 121.4392031,
#    'date': '2020-08-25',
#    'device_id': '08BEAC0286AE',
#    'name': 'A05站1月台',
#    'time': '14:40:13',
#    's_d2': 16.0,
#    'timestamp': '2020-08-25T14:40:13Z',
#    'c_d0': 11.66,
#    'c_d0_method': 'RFR/7/4.92'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '三義-1',
#    'SiteAddr': 'Sanyi',
#    's_d0': 26.0,
#    's_d1': 28.0,
#    's_h0': 96.0,
#    'area': 'taoyuan',
#    'gps_lat': 24.94385652,
#    's_t0': 25.5,
#    'gps_lon': 121.2488829,
#    'date': '2020-08-25',
#    'device_id': '08BEAC0286B2',
#    'name': '手動站：三義站-1（6B2）',
#    'time': '14:41:49',
#    's_d2': 17.0,
#    'timestamp': '2020-08-25T14:41:49Z',
#    'c_d0': 12.84,
#    'c_d0_method': 'RFR/21/4.64'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '台南-1',
#    'SiteAddr': 'Tainan',
#    's_d0': 14.0,
#    's_d1': 15.0,
#    's_h0': 100.0,
#    'area': 'tainan',
#    'gps_lat': 22.984,
#    's_t0': 26.87,
#    'gps_lon': 120.202,
#    'date': '2020-08-25',
#    'device_id': '08BEAC0286B8',
#    'name': '手動站：臺南站-1（6B8)',
#    'time': '14:42:04',
#    's_d2': 9.0,
#    'timestamp': '2020-08-25T14:42:04Z',
#    'c_d0': 8.66,
#    'c_d0_method': 'SVR/14/0.15'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '台南-2',
#    'SiteAddr': 'Tainan',
#    's_d0': 13.0,
#    's_d1': 15.0,
#    's_h0': 92.0,
#    'area': 'tainan',
#    'gps_lat': 22.984,
#    's_t0': 26.75,
#    'gps_lon': 120.202,
#    'date': '2020-08-25',
#    'device_id': '08BEAC0286C8',
#    'name': '手動站:臺南站-2（6C8)',
#    'time': '14:39:06',
#    's_d2': 9.0,
#    'timestamp': '2020-08-25T14:39:06Z',
#    'c_d0': 7.99,
#    'c_d0_method': 'SVR/14/0.15'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '板橋-2',
#    'SiteAddr': 'Banqiao',
#    's_d0': 26.0,
#    's_d1': 27.0,
#    's_h0': 79.0,
#    'area': 'NA',
#    'gps_lat': 25.012,
#    's_t0': 30.36,
#    'gps_lon': 121.458,
#    'date': '2020-08-25',
#    'device_id': '08BEAC0286CE',
#    'name': '手動站：板橋站-2（6CE)',
#    'time': '14:36:32',
#    's_d2': 16.0,
#    'timestamp': '2020-08-25T14:36:32Z',
#    'c_d0': 18.42,
#    'c_d0_method': 'RFR/7/0.15'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC0286D8',
#    'SiteAddr': 'N/A',
#    's_d0': 18.0,
#    's_d1': 20.0,
#    's_h0': 73.0,
#    'area': 'new_taipei',
#    'gps_lat': 25.01343248,
#    's_t0': 30.0,
#    'gps_lon': 121.2142493,
#    'date': '2020-08-25',
#    'device_id': '08BEAC0286D8',
#    'name': 'A18站PAO',
#    'time': '14:38:24',
#    's_d2': 13.0,
#    'timestamp': '2020-08-25T14:38:24Z',
#    'c_d0': 19.43,
#    'c_d0_method': 'RFR/21/6.8'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '忠明-1',
#    'SiteAddr': 'Zhongming',
#    's_d0': 24.0,
#    's_d1': 25.0,
#    's_h0': 88.0,
#    'area': 'taichuang',
#    'gps_lat': 24.151,
#    's_t0': 27.87,
#    'gps_lon': 120.641,
#    'date': '2020-08-25',
#    'device_id': '08BEAC0286DC',
#    'name': '手動站：忠明站-1（6DC)',
#    'time': '14:39:25',
#    's_d2': 15.0,
#    'timestamp': '2020-08-25T14:39:25Z',
#    'c_d0': 15.38,
#    'c_d0_method': 'GAM/14/0.11'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '忠明-2',
#    'SiteAddr': 'Zhongming',
#    's_d0': 24.0,
#    's_d1': 26.0,
#    's_h0': 100.0,
#    'area': 'taichuang',
#    'gps_lat': 24.151,
#    's_t0': 28.0,
#    'gps_lon': 120.641,
#    'date': '2020-08-25',
#    'device_id': '08BEAC0286DE',
#    'name': '手動站：忠明站-2（6DE)',
#    'time': '14:37:06',
#    's_d2': 15.0,
#    'timestamp': '2020-08-25T14:37:06Z',
#    'c_d0': 15.03,
#    'c_d0_method': 'GAM/14/0.11'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '桃園-2',
#    'SiteAddr': 'Taoyuan',
#    's_d0': 22.0,
#    's_d1': 23.0,
#    's_h0': 82.0,
#    'area': 'taoyuan',
#    'gps_lat': 24.994,
#    's_t0': 29.5,
#    'gps_lon': 121.305,
#    'date': '2020-08-25',
#    'device_id': '08BEAC0286E0',
#    'name': '手動站：桃園站-2（6E0)',
#    'time': '14:36:30',
#    's_d2': 15.0,
#    'timestamp': '2020-08-25T14:36:30Z',
#    'c_d0': 16.01,
#    'c_d0_method': 'SVR/14/0.15'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': 'AirBox-NUS-09',
#    'SiteAddr': 'N/A',
#    's_d0': 4.0,
#    's_d1': 4.0,
#    's_h0': 71.0,
#    'area': '',
#    'gps_lat': 1.36,
#    's_t0': 29.5,
#    'gps_lon': 103.75,
#    'date': '2020-08-25',
#    'device_id': '08BEAC0286E6',
#    'name': 'Bb12in',
#    'time': '14:39:09',
#    's_d2': 3.0,
#    'timestamp': '2020-08-25T14:39:09Z',
#    'c_d0': 'N/A',
#    'c_d0_method': 'N/A'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': 'AirBox-NUS-03',
#    'SiteAddr': 'N/A',
#    's_d0': 15.0,
#    's_d1': 18.0,
#    's_h0': 100.0,
#    'area': '',
#    'gps_lat': 1.36,
#    's_t0': 28.5,
#    'gps_lon': 103.75,
#    'date': '2020-08-25',
#    'device_id': '08BEAC0286E8',
#    'name': 'Bbout',
#    'time': '14:36:26',
#    's_d2': 11.0,
#    'timestamp': '2020-08-25T14:36:26Z',
#    'c_d0': 'N/A',
#    'c_d0_method': 'N/A'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': 'AirBox-NUS-04',
#    'SiteAddr': 'N/A',
#    's_d0': 6.0,
#    's_d1': 7.0,
#    's_h0': 87.0,
#    'area': '',
#    'gps_lat': 1.346,
#    's_t0': 29.25,
#    'gps_lon': 103.935,
#    'date': '2020-08-25',
#    'device_id': '08BEAC0286EA',
#    'name': 'Tampines_indoor',
#    'time': '14:42:03',
#    's_d2': 3.0,
#    'timestamp': '2020-08-25T14:42:03Z',
#    'c_d0': 'N/A',
#    'c_d0_method': 'N/A'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': 'AirBox-NUS-01',
#    'SiteAddr': 'N/A',
#    's_d0': 5.0,
#    's_d1': 6.0,
#    's_h0': 72.0,
#    'area': '',
#    'gps_lat': 1.425932,
#    's_t0': 29.25,
#    'gps_lon': 103.845028,
#    'date': '2020-08-25',
#    'device_id': '08BEAC0286F6',
#    'name': 'YISHUN_outdoor',
#    'time': '14:36:48',
#    's_d2': 3.0,
#    'timestamp': '2020-08-25T14:36:48Z',
#    'c_d0': 'N/A',
#    'c_d0_method': 'N/A'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': 'AirBox-NUS-02',
#    'SiteAddr': 'N/A',
#    's_d0': 2.0,
#    's_d1': 2.0,
#    's_h0': 52.0,
#    'area': '',
#    'gps_lat': 1.425982,
#    's_t0': 28.75,
#    'gps_lon': 103.845015,
#    'date': '2020-08-25',
#    'device_id': '08BEAC0286F8',
#    'name': 'YISHUN_indoor',
#    'time': '14:42:03',
#    's_d2': 1.0,
#    'timestamp': '2020-08-25T14:42:03Z',
#    'c_d0': 'N/A',
#    'c_d0_method': 'N/A'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC0286FC',
#    'SiteAddr': 'N/A',
#    's_d0': 22.0,
#    's_d1': 24.0,
#    's_h0': 78.0,
#    'area': 'changhua',
#    'gps_lat': 23.89762405,
#    's_t0': 29.61,
#    'gps_lon': 120.4617363,
#    'date': '2020-08-25',
#    'device_id': '08BEAC0286FC',
#    'name': '08BEAC286FC',
#    'time': '13:15:48',
#    's_d2': 14.0,
#    'timestamp': '2020-08-25T13:15:48Z',
#    'c_d0': 9.78,
#    'c_d0_method': 'RFR/7/20.42'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC0286FE',
#    'SiteAddr': 'N/A',
#    's_d0': 24.0,
#    's_d1': 26.0,
#    's_h0': 100.0,
#    'area': 'taichuang',
#    'gps_lat': 24.27831601,
#    's_t0': 27.25,
#    'gps_lon': 120.7188932,
#    'date': '2020-08-25',
#    'device_id': '08BEAC0286FE',
#    'name': 'EPGreen',
#    'time': '14:40:20',
#    's_d2': 16.0,
#    'timestamp': '2020-08-25T14:40:20Z',
#    'c_d0': 10.52,
#    'c_d0_method': 'GAM/7/12.33'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC028702',
#    'SiteAddr': 'N/A',
#    's_d0': 18.0,
#    's_d1': 20.0,
#    's_h0': 81.0,
#    'area': 'kaohsiung',
#    'gps_lat': 22.642467,
#    's_t0': 28.61,
#    'gps_lon': 120.318947,
#    'date': '2020-08-25',
#    'device_id': '08BEAC028702',
#    'name': '時代力量高雄黨部',
#    'time': '14:39:00',
#    's_d2': 12.0,
#    'timestamp': '2020-08-25T14:39:00Z',
#    'c_d0': 13.0,
#    'c_d0_method': 'GAM/14/3.35'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC028704',
#    'SiteAddr': 'N/A',
#    's_d0': 14.0,
#    's_d1': 15.0,
#    's_h0': 66.0,
#    'area': 'taichuang',
#    'gps_lat': 24.27581,
#    's_t0': 32.5,
#    'gps_lon': 120.518631,
#    'date': '2020-08-25',
#    'device_id': '08BEAC028704',
#    'name': 'Kingway',
#    'time': '14:38:35',
#    's_d2': 10.0,
#    'timestamp': '2020-08-25T14:38:35Z',
#    'c_d0': 9.5,
#    'c_d0_method': 'GAM/14/18.53'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC028706',
#    'SiteAddr': 'N/A',
#    's_d0': 10.0,
#    's_d1': 11.0,
#    's_h0': 82.0,
#    'area': 'tainan',
#    'gps_lat': 22.9683354,
#    's_t0': 27.25,
#    'gps_lon': 120.2105984,
#    'date': '2020-08-25',
#    'device_id': '08BEAC028706',
#    'name': '臺南市南區大忠里',
#    'time': '14:35:59',
#    's_d2': 6.0,
#    'timestamp': '2020-08-25T14:35:59Z',
#    'c_d0': 10.0,
#    'c_d0_method': 'SVR/14/2.01'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC02870A',
#    'SiteAddr': 'N/A',
#    's_d0': 10.0,
#    's_d1': 11.0,
#    's_h0': 77.0,
#    'area': 'tainan',
#    'gps_lat': 22.9694055,
#    's_t0': 27.25,
#    'gps_lon': 120.2094175,
#    'date': '2020-08-25',
#    'device_id': '08BEAC02870A',
#    'name': '臺南市南區大忠里',
#    'time': '14:38:30',
#    's_d2': 7.0,
#    'timestamp': '2020-08-25T14:38:30Z',
#    'c_d0': 10.0,
#    'c_d0_method': 'SVR/14/1.85'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC02870C',
#    'SiteAddr': 'N/A',
#    's_d0': 13.0,
#    's_d1': 16.0,
#    's_h0': 88.0,
#    'area': 'tainan',
#    'gps_lat': 23.092652,
#    's_t0': 27.0,
#    'gps_lon': 120.335812,
#    'date': '2020-08-25',
#    'device_id': '08BEAC02870C',
#    'name': 'OKFarm',
#    'time': '14:40:25',
#    's_d2': 7.0,
#    'timestamp': '2020-08-25T14:40:25Z',
#    'c_d0': 7.99,
#    'c_d0_method': 'SVR/14/18.11'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC028710',
#    'SiteAddr': 'N/A',
#    's_d0': 12.0,
#    's_d1': 13.0,
#    's_h0': 75.0,
#    'area': 'tainan',
#    'gps_lat': 22.9719025,
#    's_t0': 28.5,
#    'gps_lon': 120.2149737,
#    'date': '2020-08-25',
#    'device_id': '08BEAC028710',
#    'name': '臺南市南區大忠里',
#    'time': '14:37:58',
#    's_d2': 8.0,
#    'timestamp': '2020-08-25T14:37:58Z',
#    'c_d0': 12.0,
#    'c_d0_method': 'SVR/14/1.9'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC028712',
#    'SiteAddr': 'N/A',
#    's_d0': 23.0,
#    's_d1': 25.0,
#    's_h0': 73.0,
#    'area': 'new_taipei',
#    'gps_lat': 25.06618062,
#    's_t0': 29.61,
#    'gps_lon': 121.3611068,
#    'date': '2020-08-25',
#    'device_id': '08BEAC028712',
#    'name': 'A09站2月台',
#    'time': '14:41:32',
#    's_d2': 15.0,
#    'timestamp': '2020-08-25T14:41:32Z',
#    'c_d0': 16.69,
#    'c_d0_method': 'SVR/14/9.79'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC028714',
#    'SiteAddr': 'N/A',
#    's_d0': 22.0,
#    's_d1': 24.0,
#    's_h0': 90.0,
#    'area': 'taichuang',
#    'gps_lat': 24.251919,
#    's_t0': 29.25,
#    'gps_lon': 120.666523,
#    'date': '2020-08-25',
#    'device_id': '08BEAC028714',
#    'name': '瓜瓜樂',
#    'time': '14:40:39',
#    's_d2': 14.0,
#    'timestamp': '2020-08-25T14:40:39Z',
#    'c_d0': 14.94,
#    'c_d0_method': 'GAM/14/11.41'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC028718',
#    'SiteAddr': 'N/A',
#    's_d0': 22.0,
#    's_d1': 22.0,
#    's_h0': 79.0,
#    'area': 'new_taipei',
#    'gps_lat': 25.001,
#    's_t0': 28.75,
#    'gps_lon': 121.203,
#    'date': '2020-08-25',
#    'device_id': '08BEAC028718',
#    'name': 'A19站1月台',
#    'time': '14:36:15',
#    's_d2': 15.0,
#    'timestamp': '2020-08-25T14:36:15Z',
#    'c_d0': 14.0,
#    'c_d0_method': 'RFR/21/5.34'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC02871A',
#    'SiteAddr': 'N/A',
#    's_d0': 27.0,
#    's_d1': 27.0,
#    's_h0': 62.0,
#    'area': 'new_taipei',
#    'gps_lat': 25.0620528,
#    's_t0': 32.5,
#    'gps_lon': 121.4585188,
#    'date': '2020-08-25',
#    'device_id': '08BEAC02871A',
#    'name': 'A03站3月台',
#    'time': '14:42:01',
#    's_d2': 19.0,
#    'timestamp': '2020-08-25T14:42:01Z',
#    'c_d0': 18.5,
#    'c_d0_method': 'SVR/30/5.26'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC02871C',
#    'SiteAddr': 'N/A',
#    's_d0': 20.0,
#    's_d1': 21.0,
#    's_h0': 82.0,
#    'area': 'new_taipei',
#    'gps_lat': 25.03634591,
#    's_t0': 29.5,
#    'gps_lon': 121.2156238,
#    'date': '2020-08-25',
#    'device_id': '08BEAC02871C',
#    'name': 'A16站1月台',
#    'time': '14:42:05',
#    's_d2': 14.0,
#    'timestamp': '2020-08-25T14:42:05Z',
#    'c_d0': 13.0,
#    'c_d0_method': 'RFR/21/9.34'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC02871E',
#    'SiteAddr': 'N/A',
#    's_d0': 13.0,
#    's_d1': 14.0,
#    's_h0': 82.0,
#    'area': 'tainan',
#    'gps_lat': 22.9703386,
#    's_t0': 26.87,
#    'gps_lon': 120.21103,
#    'date': '2020-08-25',
#    'device_id': '08BEAC02871E',
#    'name': '臺南市南區大忠里',
#    'time': '14:24:00',
#    's_d2': 8.0,
#    'timestamp': '2020-08-25T14:24:00Z',
#    'c_d0': 7.99,
#    'c_d0_method': 'SVR/14/1.83'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': 'AirBox-NHRI-02',
#    'SiteAddr': 'N/A',
#    's_d0': 25.0,
#    's_d1': 27.0,
#    's_h0': 64.0,
#    'area': 'miaoli',
#    'gps_lat': 25.03048026,
#    's_t0': 31.86,
#    'gps_lon': 121.4614762,
#    'date': '2020-08-25',
#    'device_id': '08BEAC02872A',
#    'name': 'A175',
#    'time': '14:38:32',
#    's_d2': 17.0,
#    'timestamp': '2020-08-25T14:38:32Z',
#    'c_d0': 14.25,
#    'c_d0_method': 'RFR/7/1.96'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC028764',
#    'SiteAddr': 'N/A',
#    's_d0': 24.0,
#    's_d1': 26.0,
#    's_h0': 0.0,
#    'area': 'chiayi_city',
#    'gps_lat': 23.477689,
#    's_t0': -4.0,
#    'gps_lon': 120.455772,
#    'date': '2020-08-25',
#    'device_id': '08BEAC028764',
#    'name': 'Temple',
#    'time': '14:39:20',
#    's_d2': 16.0,
#    'timestamp': '2020-08-25T14:39:20Z',
#    'c_d0': 9.99,
#    'c_d0_method': 'RFR/7/2.22'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC028768',
#    'SiteAddr': 'N/A',
#    's_d0': 21.0,
#    's_d1': 23.0,
#    's_h0': 68.0,
#    'area': 'new_taipei',
#    'gps_lat': 23.478874,
#    's_t0': 30.86,
#    'gps_lon': 120.453705,
#    'date': '2020-08-25',
#    'device_id': '08BEAC028768',
#    'name': '109mtes-eastmarket',
#    'time': '14:39:36',
#    's_d2': 14.0,
#    'timestamp': '2020-08-25T14:39:36Z',
#    'c_d0': 8.08,
#    'c_d0_method': 'RFR/7/2.19'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '前金-1',
#    'SiteAddr': 'Qianjin',
#    's_d0': 8.0,
#    's_d1': 10.0,
#    's_h0': 100.0,
#    'area': 'kaohsiung',
#    'gps_lat': 22.632,
#    's_t0': 27.62,
#    'gps_lon': 120.287,
#    'date': '2020-08-25',
#    'device_id': '08BEAC028770',
#    'name': '手動站：前金站-1（770)',
#    'time': '14:40:28',
#    's_d2': 5.0,
#    'timestamp': '2020-08-25T14:40:28Z',
#    'c_d0': 8.0,
#    'c_d0_method': 'GAM/14/0.15'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '前金-2',
#    'SiteAddr': 'Qianjin',
#    's_d0': 7.0,
#    's_d1': 9.0,
#    's_h0': 100.0,
#    'area': 'kaohsiung',
#    'gps_lat': 22.632,
#    's_t0': 27.62,
#    'gps_lon': 120.287,
#    'date': '2020-08-25',
#    'device_id': '08BEAC028772',
#    'name': '手動站：前金站-2（772)',
#    'time': '14:39:34',
#    's_d2': 4.0,
#    'timestamp': '2020-08-25T14:39:34Z',
#    'c_d0': 7.0,
#    'c_d0_method': 'GAM/14/0.15'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': 'iTribe排灣部落',
#    'SiteAddr': '',
#    's_d0': 19.0,
#    's_d1': 20.0,
#    's_h0': 100.0,
#    'area': 'pingtung',
#    'gps_lat': 22.629,
#    's_t0': 27.5,
#    'gps_lon': 120.626,
#    'date': '2020-08-25',
#    'device_id': '08BEAC028774',
#    'name': 'iTribe排灣部落',
#    'time': '14:41:56',
#    's_d2': 12.0,
#    'timestamp': '2020-08-25T14:41:56Z',
#    'c_d0': 6.91,
#    'c_d0_method': 'RFR/7/14.98'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC028776',
#    'SiteAddr': 'N/A',
#    's_d0': 22.0,
#    's_d1': 24.0,
#    's_h0': 83.0,
#    'area': 'chiayi_county',
#    'gps_lat': 23.562,
#    's_t0': 27.37,
#    'gps_lon': 120.475,
#    'date': '2020-08-25',
#    'device_id': '08BEAC028776',
#    'name': '中正大學圖書館',
#    'time': '14:39:35',
#    's_d2': 14.0,
#    'timestamp': '2020-08-25T14:39:35Z',
#    'c_d0': 9.72,
#    'c_d0_method': 'RFR/7/11.54'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC028780',
#    'SiteAddr': 'N/A',
#    's_d0': 16.0,
#    's_d1': 17.0,
#    's_h0': 95.0,
#    'area': 'taipei',
#    'gps_lat': 25.119,
#    's_t0': 30.36,
#    'gps_lon': 121.469,
#    'date': '2020-08-25',
#    'device_id': '08BEAC028780',
#    'name': '關渡自然公園-入口',
#    'time': '14:36:53',
#    's_d2': 11.0,
#    'timestamp': '2020-08-25T14:36:53Z',
#    'c_d0': 10.76,
#    'c_d0_method': 'SVR/30/8.92'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC02878E',
#    'SiteAddr': 'N/A',
#    's_d0': 1.0,
#    's_d1': 1.0,
#    's_h0': 50.0,
#    'area': 'taichuang',
#    'gps_lat': 24.1113428,
#    's_t0': 29.75,
#    'gps_lon': 120.659393,
#    'date': '2020-08-25',
#    'device_id': '08BEAC02878E',
#    'name': 'AAA2',
#    'time': '14:41:57',
#    's_d2': 0.0,
#    'timestamp': '2020-08-25T14:41:57Z',
#    'c_d0': 1.0,
#    'c_d0_method': 'GAM/14/4.89'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC0287A4',
#    'SiteAddr': 'N/A',
#    's_d0': 23.0,
#    's_d1': 31.0,
#    's_h0': 100.0,
#    'area': 'changhua',
#    'gps_lat': 24.03887415,
#    's_t0': 28.0,
#    'gps_lon': 120.3847512,
#    'date': '2020-08-25',
#    'device_id': '08BEAC0287A4',
#    'name': 'AB_SLfarm',
#    'time': '14:38:06',
#    's_d2': 11.0,
#    'timestamp': '2020-08-25T14:38:06Z',
#    'c_d0': 10.79,
#    'c_d0_method': 'RFR/7/16.25'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC0287B2',
#    'SiteAddr': 'N/A',
#    's_d0': 13.0,
#    's_d1': 14.0,
#    's_h0': 89.0,
#    'area': 'pingtung',
#    'gps_lat': 22.567,
#    's_t0': 28.25,
#    'gps_lon': 120.567,
#    'date': '2020-08-25',
#    'device_id': '08BEAC0287B2',
#    'name': 'WanluamAirBox',
#    'time': '14:39:30',
#    's_d2': 8.0,
#    'timestamp': '2020-08-25T14:39:30Z',
#    'c_d0': 5.72,
#    'c_d0_method': 'RFR/7/14.31'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC0287B4',
#    'SiteAddr': 'N/A',
#    's_d0': 23.0,
#    's_d1': 26.0,
#    's_h0': 100.0,
#    'area': 'taichuang',
#    'gps_lat': 24.39605979,
#    's_t0': 29.36,
#    'gps_lon': 120.6360992,
#    'date': '2020-08-25',
#    'device_id': '08BEAC0287B4',
#    'name': '環球預拌混凝土烏日廠出入口',
#    'time': '14:36:27',
#    's_d2': 15.0,
#    'timestamp': '2020-08-25T14:36:27Z',
#    'c_d0': 9.97,
#    'c_d0_method': 'GAM/7/12.53'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC0287B6',
#    'SiteAddr': 'N/A',
#    's_d0': 27.0,
#    's_d1': 29.0,
#    's_h0': 100.0,
#    'area': 'taichuang',
#    'gps_lat': 24.15515067,
#    's_t0': 26.0,
#    'gps_lon': 120.5821589,
#    'date': '2020-08-25',
#    'device_id': '08BEAC0287B6',
#    'name': '聯好環保股份有限公司出入口',
#    'time': '14:40:35',
#    's_d2': 18.0,
#    'timestamp': '2020-08-25T14:40:35Z',
#    'c_d0': 13.61,
#    'c_d0_method': 'GAM/14/5.98'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC0287EE',
#    'SiteAddr': 'N/A',
#    's_d0': 11.0,
#    's_d1': 12.0,
#    's_h0': 69.0,
#    'area': 'kaohsiung',
#    'gps_lat': 22.594663,
#    's_t0': 29.36,
#    'gps_lon': 120.400583,
#    'date': '2020-08-25',
#    'device_id': '08BEAC0287EE',
#    'name': '高英工商',
#    'time': '14:41:50',
#    's_d2': 8.0,
#    'timestamp': '2020-08-25T14:41:50Z',
#    'c_d0': 11.0,
#    'c_d0_method': 'GAM/14/12.32'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '屏東-1',
#    'SiteAddr': 'Pingtung',
#    's_d0': 23.0,
#    's_d1': 25.0,
#    's_h0': 88.0,
#    'area': 'taipei',
#    'gps_lat': 25.03801697,
#    's_t0': 27.0,
#    'gps_lon': 121.5456786,
#    'date': '2020-08-25',
#    'device_id': '08BEAC0287F6',
#    'name': '手動站：屏東站-1（7F6）',
#    'time': '14:36:55',
#    's_d2': 15.0,
#    'timestamp': '2020-08-25T14:36:55Z',
#    'c_d0': 10.84,
#    'c_d0_method': 'SVR/30/3.93'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC028810',
#    'SiteAddr': 'N/A',
#    's_d0': 19.0,
#    's_d1': 22.0,
#    's_h0': 74.0,
#    'area': 'taichuang',
#    'gps_lat': 24.207,
#    's_t0': 29.36,
#    'gps_lon': 120.653,
#    'date': '2020-08-25',
#    'device_id': '08BEAC028810',
#    'name': '總茂環保2',
#    'time': '14:41:12',
#    's_d2': 13.0,
#    'timestamp': '2020-08-25T14:41:12Z',
#    'c_d0': 12.12,
#    'c_d0_method': 'GAM/14/6.24'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC028814',
#    'SiteAddr': 'N/A',
#    's_d0': 23.0,
#    's_d1': 26.0,
#    's_h0': 100.0,
#    'area': 'taichuang',
#    'gps_lat': 24.277889,
#    's_t0': 28.11,
#    'gps_lon': 120.674903,
#    'date': '2020-08-25',
#    'device_id': '08BEAC028814',
#    'name': '麗榮實業有限公司',
#    'time': '14:39:41',
#    's_d2': 15.0,
#    'timestamp': '2020-08-25T14:39:41Z',
#    'c_d0': 14.63,
#    'c_d0_method': 'GAM/14/14.41'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC028816',
#    'SiteAddr': 'N/A',
#    's_d0': 22.0,
#    's_d1': 24.0,
#    's_h0': 78.0,
#    'area': 'taichuang',
#    'gps_lat': 24.346437,
#    's_t0': 27.62,
#    'gps_lon': 120.643484,
#    'date': '2020-08-25',
#    'device_id': '08BEAC028816',
#    'name': '外埔國際壘球場',
#    'time': '14:36:15',
#    's_d2': 15.0,
#    'timestamp': '2020-08-25T14:36:15Z',
#    'c_d0': 11.56,
#    'c_d0_method': 'GAM/7/12.39'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC02883C',
#    'SiteAddr': 'N/A',
#    's_d0': 7.0,
#    's_d1': 9.0,
#    's_h0': 58.0,
#    'area': 'kaohsiung',
#    'gps_lat': 22.612555,
#    's_t0': 30.36,
#    'gps_lon': 120.322122,
#    'date': '2020-08-25',
#    'device_id': '08BEAC02883C',
#    'name': 'Airbox365',
#    'time': '14:37:05',
#    's_d2': 5.0,
#    'timestamp': '2020-08-25T14:37:05Z',
#    'c_d0': 7.0,
#    'c_d0_method': 'GAM/14/4.18'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC02883E',
#    'SiteAddr': 'N/A',
#    's_d0': 21.0,
#    's_d1': 22.0,
#    's_h0': 74.0,
#    'area': 'new_taipei',
#    'gps_lat': 25.002,
#    's_t0': 29.75,
#    'gps_lon': 121.141,
#    'date': '2020-08-25',
#    'device_id': '08BEAC02883E',
#    'name': '永興宮',
#    'time': '14:37:28',
#    's_d2': 15.0,
#    'timestamp': '2020-08-25T14:37:28Z',
#    'c_d0': 12.04,
#    'c_d0_method': 'RFR/21/8.37'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC028840',
#    'SiteAddr': 'N/A',
#    's_d0': 17.0,
#    's_d1': 18.0,
#    's_h0': 69.0,
#    'area': 'new_taipei',
#    'gps_lat': 25.002,
#    's_t0': 31.0,
#    'gps_lon': 121.137,
#    'date': '2020-08-25',
#    'device_id': '08BEAC028840',
#    'name': '弘誓佛院',
#    'time': '14:37:55',
#    's_d2': 13.0,
#    'timestamp': '2020-08-25T14:37:55Z',
#    'c_d0': 14.04,
#    'c_d0_method': 'RFR/21/8.68'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC028848',
#    'SiteAddr': 'N/A',
#    's_d0': 26.0,
#    's_d1': 29.0,
#    's_h0': 61.0,
#    'area': 'new_taipei',
#    'gps_lat': 25.076,
#    's_t0': 33.86,
#    'gps_lon': 121.169,
#    'date': '2020-08-25',
#    'device_id': '08BEAC028848',
#    'name': '富文宮',
#    'time': '14:41:24',
#    's_d2': 19.0,
#    'timestamp': '2020-08-25T14:41:24Z',
#    'c_d0': 12.84,
#    'c_d0_method': 'RFR/21/14.12'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC02884C',
#    'SiteAddr': 'N/A',
#    's_d0': 18.0,
#    's_d1': 20.0,
#    's_h0': 59.0,
#    'area': 'new_taipei',
#    'gps_lat': 25.045,
#    's_t0': 29.75,
#    'gps_lon': 121.532,
#    'date': '2020-08-25',
#    'device_id': '08BEAC02884C',
#    'name': '光華Air Box',
#    'time': '14:41:20',
#    's_d2': 11.0,
#    'timestamp': '2020-08-25T14:41:20Z',
#    'c_d0': 11.39,
#    'c_d0_method': 'SVR/30/2.43'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC02885A',
#    'SiteAddr': 'N/A',
#    's_d0': 17.0,
#    's_d1': 18.0,
#    's_h0': 72.0,
#    'area': 'pingtung',
#    'gps_lat': 22.82605905,
#    's_t0': 29.25,
#    'gps_lon': 120.598956,
#    'date': '2020-08-25',
#    'device_id': '08BEAC02885A',
#    'name': '高樹國小',
#    'time': '14:40:45',
#    's_d2': 12.0,
#    'timestamp': '2020-08-25T14:40:45Z',
#    'c_d0': 11.42,
#    'c_d0_method': 'GAM/14/9.49'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC02885E',
#    'SiteAddr': 'N/A',
#    's_d0': 26.0,
#    's_d1': 28.0,
#    's_h0': 90.0,
#    'area': 'changhua',
#    'gps_lat': 24.0,
#    's_t0': 29.0,
#    'gps_lon': 120.598,
#    'date': '2020-08-25',
#    'device_id': '08BEAC02885E',
#    'name': '大葉大學-工學院大樓',
#    'time': '14:39:47',
#    's_d2': 17.0,
#    'timestamp': '2020-08-25T14:39:47Z',
#    'c_d0': 12.47,
#    'c_d0_method': 'RFR/7/9.28'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC028868',
#    'SiteAddr': 'N/A',
#    's_d0': 26.0,
#    's_d1': 27.0,
#    's_h0': 100.0,
#    'area': 'NA',
#    'gps_lat': 24.2766934,
#    's_t0': 26.87,
#    'gps_lon': 120.6955657,
#    'date': '2020-08-25',
#    'device_id': '08BEAC028868',
#    'name': '佳生預拌混凝土神岡廠行車路徑',
#    'time': '14:40:53',
#    's_d2': 17.0,
#    'timestamp': '2020-08-25T14:40:53Z',
#    'c_d0': 12.14,
#    'c_d0_method': 'GAM/7/13.46'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC02886A',
#    'SiteAddr': 'N/A',
#    's_d0': 18.0,
#    's_d1': 20.0,
#    's_h0': 92.0,
#    'area': 'taichuang',
#    'gps_lat': 24.27659991,
#    's_t0': 27.75,
#    'gps_lon': 120.6959908,
#    'date': '2020-08-25',
#    'device_id': '08BEAC02886A',
#    'name': '民峰預拌混凝土大雅廠出入口',
#    'time': '14:40:38',
#    's_d2': 12.0,
#    'timestamp': '2020-08-25T14:40:38Z',
#    'c_d0': 9.07,
#    'c_d0_method': 'GAM/7/13.44'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC02886C',
#    'SiteAddr': 'N/A',
#    's_d0': 28.0,
#    's_d1': 30.0,
#    's_h0': 100.0,
#    'area': 'taichuang',
#    'gps_lat': 24.15473599,
#    's_t0': 26.0,
#    'gps_lon': 120.5826777,
#    'date': '2020-08-25',
#    'device_id': '08BEAC02886C',
#    'name': '聯好環保股份有限公司行車路徑',
#    'time': '14:37:31',
#    's_d2': 18.0,
#    'timestamp': '2020-08-25T14:37:31Z',
#    'c_d0': 13.67,
#    'c_d0_method': 'GAM/14/5.93'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC02886E',
#    'SiteAddr': 'N/A',
#    's_d0': 22.0,
#    's_d1': 24.0,
#    's_h0': 94.0,
#    'area': 'taichuang',
#    'gps_lat': 24.20917166,
#    's_t0': 28.5,
#    'gps_lon': 120.5098966,
#    'date': '2020-08-25',
#    'device_id': '08BEAC02886E',
#    'name': '東億環保（水）',
#    'time': '14:41:43',
#    's_d2': 16.0,
#    'timestamp': '2020-08-25T14:41:43Z',
#    'c_d0': 13.72,
#    'c_d0_method': 'GAM/14/14.74'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC02887E',
#    'SiteAddr': 'N/A',
#    's_d0': 25.0,
#    's_d1': 27.0,
#    's_h0': 85.0,
#    'area': 'NA',
#    'gps_lat': 24.10471107,
#    's_t0': 28.86,
#    'gps_lon': 120.631101,
#    'date': '2020-08-25',
#    'device_id': '08BEAC02887E',
#    'name': '環球預拌混凝土烏日廠行車路徑',
#    'time': '14:42:02',
#    's_d2': 17.0,
#    'timestamp': '2020-08-25T14:42:02Z',
#    'c_d0': 15.8,
#    'c_d0_method': 'GAM/14/5.35'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC028880',
#    'SiteAddr': 'N/A',
#    's_d0': 24.0,
#    's_d1': 26.0,
#    's_h0': 100.0,
#    'area': 'taichuang',
#    'gps_lat': 24.21896993,
#    's_t0': 28.0,
#    'gps_lon': 120.6597032,
#    'date': '2020-08-25',
#    'device_id': '08BEAC028880',
#    'name': '民峰實業股份有限公司大雅預拌混凝土廠行車路徑',
#    'time': '14:39:30',
#    's_d2': 17.0,
#    'timestamp': '2020-08-25T14:39:30Z',
#    'c_d0': 15.03,
#    'c_d0_method': 'GAM/14/7.68'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC02889C',
#    'SiteAddr': 'N/A',
#    's_d0': 21.0,
#    's_d1': 23.0,
#    's_h0': 71.0,
#    'area': 'new_taipei',
#    'gps_lat': 25.0241946,
#    's_t0': 30.0,
#    'gps_lon': 121.2211894,
#    'date': '2020-08-25',
#    'device_id': '08BEAC02889C',
#    'name': 'A17站2月台',
#    'time': '14:37:40',
#    's_d2': 16.0,
#    'timestamp': '2020-08-25T14:37:40Z',
#    'c_d0': 12.04,
#    'c_d0_method': 'RFR/21/8.1'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC02889E',
#    'SiteAddr': 'N/A',
#    's_d0': 21.0,
#    's_d1': 24.0,
#    's_h0': 62.0,
#    'area': 'new_taipei',
#    'gps_lat': 25.033,
#    's_t0': 32.25,
#    'gps_lon': 121.422,
#    'date': '2020-08-25',
#    'device_id': '08BEAC02889E',
#    'name': 'A06站PAO',
#    'time': '14:38:08',
#    's_d2': 13.0,
#    'timestamp': '2020-08-25T14:38:08Z',
#    'c_d0': 14.28,
#    'c_d0_method': 'RFR/7/4.34'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC0288A0',
#    'SiteAddr': 'N/A',
#    's_d0': 26.0,
#    's_d1': 27.0,
#    's_h0': 66.0,
#    'area': 'new_taipei',
#    'gps_lat': 25.05373326,
#    's_t0': 31.36,
#    'gps_lon': 121.4396466,
#    'date': '2020-08-25',
#    'device_id': '08BEAC0288A0',
#    'name': 'A05站PAO',
#    'time': '14:41:23',
#    's_d2': 18.0,
#    'timestamp': '2020-08-25T14:41:23Z',
#    'c_d0': 18.19,
#    'c_d0_method': 'RFR/7/4.93'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC0288A2',
#    'SiteAddr': 'N/A',
#    's_d0': 20.0,
#    's_d1': 23.0,
#    's_h0': 82.0,
#    'area': 'new_taipei',
#    'gps_lat': 25.024204,
#    's_t0': 29.11,
#    'gps_lon': 121.221109,
#    'date': '2020-08-25',
#    'device_id': '08BEAC0288A2',
#    'name': 'A17站PAO',
#    'time': '14:37:52',
#    's_d2': 14.0,
#    'timestamp': '2020-08-25T14:37:52Z',
#    'c_d0': 13.0,
#    'c_d0_method': 'RFR/21/8.1'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC0288A4',
#    'SiteAddr': 'N/A',
#    's_d0': 24.0,
#    's_d1': 26.0,
#    's_h0': 59.0,
#    'area': 'new_taipei',
#    'gps_lat': 25.03330422,
#    's_t0': 33.25,
#    'gps_lon': 121.422625,
#    'date': '2020-08-25',
#    'device_id': '08BEAC0288A4',
#    'name': 'A06站2月台',
#    'time': '14:41:35',
#    's_d2': 16.0,
#    'timestamp': '2020-08-25T14:41:35Z',
#    'c_d0': 11.88,
#    'c_d0_method': 'RFR/7/4.3'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC0288A6',
#    'SiteAddr': 'N/A',
#    's_d0': 27.0,
#    's_d1': 29.0,
#    's_h0': 75.0,
#    'area': 'new_taipei',
#    'gps_lat': 25.06,
#    's_t0': 29.61,
#    'gps_lon': 121.37,
#    'date': '2020-08-25',
#    'device_id': '08BEAC0288A6',
#    'name': 'A08站PAO',
#    'time': '14:23:43',
#    's_d2': 19.0,
#    'timestamp': '2020-08-25T14:23:43Z',
#    'c_d0': 19.17,
#    'c_d0_method': 'SVR/14/9.82'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC0288A8',
#    'SiteAddr': 'N/A',
#    's_d0': 21.0,
#    's_d1': 23.0,
#    's_h0': 99.0,
#    'area': 'new_taipei',
#    'gps_lat': 25.03669297,
#    's_t0': 28.86,
#    'gps_lon': 121.2158502,
#    'date': '2020-08-25',
#    'device_id': '08BEAC0288A8',
#    'name': 'A16站PAO',
#    'time': '14:40:05',
#    's_d2': 14.0,
#    'timestamp': '2020-08-25T14:40:05Z',
#    'c_d0': 12.04,
#    'c_d0_method': 'RFR/21/9.38'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC0288AC',
#    'SiteAddr': 'N/A',
#    's_d0': 23.0,
#    's_d1': 24.0,
#    's_h0': 85.0,
#    'area': 'changhua',
#    'gps_lat': 24.29445833,
#    's_t0': 28.11,
#    'gps_lon': 120.6267983,
#    'date': '2020-08-25',
#    'device_id': '08BEAC0288AC',
#    'name': '陸誠預拌混凝土',
#    'time': '14:40:18',
#    's_d2': 15.0,
#    'timestamp': '2020-08-25T14:40:18Z',
#    'c_d0': 14.8,
#    'c_d0_method': 'GAM/14/15.91'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC0288AE',
#    'SiteAddr': 'N/A',
#    's_d0': 21.0,
#    's_d1': 22.0,
#    's_h0': 85.0,
#    'area': 'new_taipei',
#    'gps_lat': 25.0137186,
#    's_t0': 29.36,
#    'gps_lon': 121.2142854,
#    'date': '2020-08-25',
#    'device_id': '08BEAC0288AE',
#    'name': 'A18站2月台',
#    'time': '14:38:48',
#    's_d2': 15.0,
#    'timestamp': '2020-08-25T14:38:48Z',
#    'c_d0': 12.04,
#    'c_d0_method': 'RFR/21/6.83'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC0288B0',
#    'SiteAddr': 'N/A',
#    's_d0': 26.0,
#    's_d1': 28.0,
#    's_h0': 72.0,
#    'area': 'new_taipei',
#    'gps_lat': 25.06135746,
#    's_t0': 31.5,
#    'gps_lon': 121.4598319,
#    'date': '2020-08-25',
#    'device_id': '08BEAC0288B0',
#    'name': 'A03站PAO',
#    'time': '14:37:04',
#    's_d2': 18.0,
#    'timestamp': '2020-08-25T14:37:04Z',
#    'c_d0': 16.92,
#    'c_d0_method': 'SVR/30/5.11'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC0288B2',
#    'SiteAddr': 'N/A',
#    's_d0': 27.0,
#    's_d1': 28.0,
#    's_h0': 69.0,
#    'area': 'new_taipei',
#    'gps_lat': 25.05399,
#    's_t0': 30.75,
#    'gps_lon': 121.483509,
#    'date': '2020-08-25',
#    'device_id': '08BEAC0288B2',
#    'name': 'A02站月台層',
#    'time': '14:40:56',
#    's_d2': 19.0,
#    'timestamp': '2020-08-25T14:40:56Z',
#    'c_d0': 16.76,
#    'c_d0_method': 'SVR/30/2.59'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC0288B4',
#    'SiteAddr': 'N/A',
#    's_d0': 20.0,
#    's_d1': 22.0,
#    's_h0': 76.0,
#    'area': 'new_taipei',
#    'gps_lat': 25.08104969,
#    's_t0': 29.5,
#    'gps_lon': 121.2851864,
#    'date': '2020-08-25',
#    'device_id': '08BEAC0288B4',
#    'name': 'A10站PAO',
#    'time': '14:39:35',
#    's_d2': 13.0,
#    'timestamp': '2020-08-25T14:39:35Z',
#    'c_d0': 14.98,
#    'c_d0_method': 'SVR/14/9.75'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC0288B6',
#    'SiteAddr': 'N/A',
#    's_d0': 19.0,
#    's_d1': 21.0,
#    's_h0': 81.0,
#    'area': 'new_taipei',
#    'gps_lat': 25.056,
#    's_t0': 29.0,
#    'gps_lon': 121.21,
#    'date': '2020-08-25',
#    'device_id': '08BEAC0288B6',
#    'name': 'A15站PAO',
#    'time': '14:36:07',
#    's_d2': 13.0,
#    'timestamp': '2020-08-25T14:36:07Z',
#    'c_d0': 11.98,
#    'c_d0_method': 'RFR/21/11.47'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC0288B8',
#    'SiteAddr': 'N/A',
#    's_d0': 20.0,
#    's_d1': 23.0,
#    's_h0': 73.0,
#    'area': 'new_taipei',
#    'gps_lat': 25.08068586,
#    's_t0': 30.5,
#    'gps_lon': 121.2845566,
#    'date': '2020-08-25',
#    'device_id': '08BEAC0288B8',
#    'name': 'A10站2月台',
#    'time': '14:42:02',
#    's_d2': 14.0,
#    'timestamp': '2020-08-25T14:42:02Z',
#    'c_d0': 16.04,
#    'c_d0_method': 'SVR/14/9.73'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': 'iTribe松林部落',
#    'SiteAddr': '',
#    's_d0': 23.0,
#    's_d1': 25.0,
#    's_h0': 84.0,
#    'area': 'NA',
#    'gps_lat': 23.97,
#    's_t0': 24.62,
#    'gps_lon': 121.098,
#    'date': '2020-08-25',
#    'device_id': '08BEAC0288BC',
#    'name': 'iTribe松林部落',
#    'time': '14:41:35',
#    's_d2': 15.0,
#    'timestamp': '2020-08-25T14:41:35Z',
#    'c_d0': 11.82,
#    'c_d0_method': 'RFR/14/42.45'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC0288BE',
#    'SiteAddr': 'N/A',
#    's_d0': 19.0,
#    's_d1': 23.0,
#    's_h0': 77.0,
#    'area': 'new_taipei',
#    'gps_lat': 25.002427,
#    's_t0': 29.75,
#    'gps_lon': 121.2028373,
#    'date': '2020-08-25',
#    'device_id': '08BEAC0288BE',
#    'name': 'A19站PAO',
#    'time': '14:36:56',
#    's_d2': 14.0,
#    'timestamp': '2020-08-25T14:36:56Z',
#    'c_d0': 11.98,
#    'c_d0_method': 'RFR/21/5.5'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC0288C0',
#    'SiteAddr': 'N/A',
#    's_d0': 27.0,
#    's_d1': 30.0,
#    's_h0': 78.0,
#    'area': 'new_taipei',
#    'gps_lat': 25.054,
#    's_t0': 29.61,
#    'gps_lon': 121.482,
#    'date': '2020-08-25',
#    'device_id': '08BEAC0288C0',
#    'name': 'A02站PAO',
#    'time': '14:37:19',
#    's_d2': 18.0,
#    'timestamp': '2020-08-25T14:37:19Z',
#    'c_d0': 15.55,
#    'c_d0_method': 'SVR/30/2.73'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC0288C2',
#    'SiteAddr': 'N/A',
#    's_d0': 20.0,
#    's_d1': 21.0,
#    's_h0': 84.0,
#    'area': 'new_taipei',
#    'gps_lat': 24.98048954,
#    's_t0': 28.5,
#    'gps_lon': 121.2162134,
#    'date': '2020-08-25',
#    'device_id': '08BEAC0288C2',
#    'name': 'A20站PAO',
#    'time': '14:39:18',
#    's_d2': 14.0,
#    'timestamp': '2020-08-25T14:39:18Z',
#    'c_d0': 13.0,
#    'c_d0_method': 'RFR/21/3.3'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC0288C4',
#    'SiteAddr': 'N/A',
#    's_d0': 19.0,
#    's_d1': 22.0,
#    's_h0': 74.0,
#    'area': 'new_taipei',
#    'gps_lat': 25.0864907,
#    's_t0': 29.86,
#    'gps_lon': 121.2663736,
#    'date': '2020-08-25',
#    'device_id': '08BEAC0288C4',
#    'name': 'A11站PAO',
#    'time': '14:36:45',
#    's_d2': 13.0,
#    'timestamp': '2020-08-25T14:36:45Z',
#    'c_d0': 14.87,
#    'c_d0_method': 'SVR/14/10.86'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': 'iTribe潭南部落',
#    'SiteAddr': '',
#    's_d0': 18.0,
#    's_d1': 20.0,
#    's_h0': 83.0,
#    'area': 'nantou',
#    'gps_lat': 23.821,
#    's_t0': 26.5,
#    'gps_lon': 120.94,
#    'date': '2020-08-25',
#    'device_id': '08BEAC0288C8',
#    'name': 'iTribe潭南部落',
#    'time': '14:38:59',
#    's_d2': 12.0,
#    'timestamp': '2020-08-25T14:38:59Z',
#    'c_d0': 11.17,
#    'c_d0_method': 'RFR/14/27.88'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': 'iTribe加羅板部落',
#    'SiteAddr': '',
#    's_d0': 9.0,
#    's_d1': 11.0,
#    's_h0': 73.0,
#    'area': 'NA',
#    'gps_lat': 22.359,
#    's_t0': 30.25,
#    'gps_lon': 120.879,
#    'date': '2020-08-25',
#    'device_id': '08BEAC0288CA',
#    'name': '\xa0iTribe加羅板部落',
#    'time': '14:37:16',
#    's_d2': 6.0,
#    'timestamp': '2020-08-25T14:37:16Z',
#    'c_d0': 9.0,
#    'c_d0_method': 'RFR/14/45.54'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': 'iTribe明德部落',
#    'SiteAddr': '',
#    's_d0': 19.0,
#    's_d1': 22.0,
#    's_h0': 81.0,
#    'area': 'nantou',
#    'gps_lat': 23.695,
#    's_t0': 26.75,
#    'gps_lon': 120.857,
#    'date': '2020-08-25',
#    'device_id': '08BEAC0288CC',
#    'name': 'iTribe明德部落',
#    'time': '14:39:48',
#    's_d2': 12.0,
#    'timestamp': '2020-08-25T14:39:48Z',
#    'c_d0': 11.15,
#    'c_d0_method': 'RFR/14/29.9'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': 'iTribe眉原部落',
#    'SiteAddr': '',
#    's_d0': 20.0,
#    's_d1': 23.0,
#    's_h0': 71.0,
#    'area': 'nantou',
#    'gps_lat': 24.072,
#    's_t0': 28.36,
#    'gps_lon': 120.982,
#    'date': '2020-08-25',
#    'device_id': '08BEAC0288CE',
#    'name': 'iTribe眉原部落',
#    'time': '14:39:53',
#    's_d2': 14.0,
#    'timestamp': '2020-08-25T14:39:53Z',
#    'c_d0': 11.47,
#    'c_d0_method': 'RFR/14/34.97'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': 'iTribe伊達邵部落',
#    'SiteAddr': '',
#    's_d0': 5.0,
#    's_d1': 5.0,
#    's_h0': 62.0,
#    'area': 'taitung',
#    'gps_lat': 23.042,
#    's_t0': 34.11,
#    'gps_lon': 121.195,
#    'date': '2020-08-25',
#    'device_id': '08BEAC0288D0',
#    'name': 'iTribe振興部落',
#    'time': '14:41:15',
#    's_d2': 3.0,
#    'timestamp': '2020-08-25T14:41:15Z',
#    'c_d0': 5.0,
#    'c_d0_method': 'SVR/14/32.24'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': 'iTribe新化部落',
#    'SiteAddr': '',
#    's_d0': 12.0,
#    's_d1': 14.0,
#    's_h0': 68.0,
#    'area': 'taitung',
#    'gps_lat': 22.381,
#    's_t0': 28.5,
#    'gps_lon': 120.857,
#    'date': '2020-08-25',
#    'device_id': '08BEAC0288D2',
#    'name': 'iTribe新化部落',
#    'time': '14:39:46',
#    's_d2': 7.0,
#    'timestamp': '2020-08-25T14:39:46Z',
#    'c_d0': 12.0,
#    'c_d0_method': 'RFR/14/47.55'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC0288D4',
#    'SiteAddr': 'N/A',
#    's_d0': 17.0,
#    's_d1': 18.0,
#    's_h0': 62.0,
#    'area': 'changhua',
#    'gps_lat': 24.06775794,
#    's_t0': 31.75,
#    'gps_lon': 120.5383809,
#    'date': '2020-08-25',
#    'device_id': '08BEAC0288D4',
#    'name': '彰化南瑤宮',
#    'time': '14:36:47',
#    's_d2': 11.0,
#    'timestamp': '2020-08-25T14:36:47Z',
#    'c_d0': 9.69,
#    'c_d0_method': 'RFR/7/0.42'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC0288D6',
#    'SiteAddr': 'N/A',
#    's_d0': 104.0,
#    's_d1': 108.0,
#    's_h0': 64.0,
#    'area': 'new_taipei',
#    'gps_lat': 24.98369499,
#    's_t0': 32.75,
#    'gps_lon': 121.2503149,
#    'date': '2020-08-25',
#    'device_id': '08BEAC0288D6',
#    'name': '紫竹林',
#    'time': '14:41:43',
#    's_d2': 89.0,
#    'timestamp': '2020-08-25T14:41:43Z',
#    'c_d0': 13.95,
#    'c_d0_method': 'SVR/14/5.55'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC0288D8',
#    'SiteAddr': 'N/A',
#    's_d0': 21.0,
#    's_d1': 23.0,
#    's_h0': 66.0,
#    'area': 'new_taipei',
#    'gps_lat': 25.02238331,
#    's_t0': 31.11,
#    'gps_lon': 121.2787801,
#    'date': '2020-08-25',
#    'device_id': '08BEAC0288D8',
#    'name': '泓德佛堂',
#    'time': '14:31:48',
#    's_d2': 15.0,
#    'timestamp': '2020-08-25T14:31:48Z',
#    'c_d0': 17.24,
#    'c_d0_method': 'SVR/14/3.97'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC0288DE',
#    'SiteAddr': 'N/A',
#    's_d0': 32.0,
#    's_d1': 37.0,
#    's_h0': 71.0,
#    'area': 'new_taipei',
#    'gps_lat': 24.907,
#    's_t0': 30.75,
#    'gps_lon': 121.142,
#    'date': '2020-08-25',
#    'device_id': '08BEAC0288DE',
#    'name': '錫福宮',
#    'time': '14:36:14',
#    's_d2': 21.0,
#    'timestamp': '2020-08-25T14:36:14Z',
#    'c_d0': 18.99,
#    'c_d0_method': 'RFR/21/8.08'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC0288EC',
#    'SiteAddr': 'N/A',
#    's_d0': 15.0,
#    's_d1': 19.0,
# ...
#    'device_id': '08BEAC0A04FC',
#    'gps_lon': 121.3594985,
#    's_g1': 0.0,
#    'time': '14:43:00',
#    'model': 'AI-1003WN',
#    'timestamp': '2020-08-25T14:43:00Z',
#    'c_d0': 17.84,
#    'c_d0_method': 'SVR/14/8.94'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '雲林縣縣立崇文國小',
#    'SiteAddr': '雲林縣口湖鄉蚵寮村七九號',
#    'hcho': '0',
#    's_d2': 7.0,
#    'odm': 'acelink.edimax',
#    's_d0': 11.0,
#    's_d1': 11.0,
#    's_h0': 100.0,
#    'gps_lat': 23.57531263,
#    's_t0': 30.1,
#    'adf_status': '0',
#    'fw_ver': 'v1.06',
#    'date': '2020-08-25',
#    'device_id': '08BEAC0A04FE',
#    'gps_lon': 120.176909,
#    's_g1': 0.0,
#    'time': '14:39:48',
#    'model': 'AI-1003WN',
#    'timestamp': '2020-08-25T14:39:48Z',
#    'c_d0': 11.0,
#    'c_d0_method': 'RFR/7/14.06'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '雲林縣縣立口湖國小',
#    'SiteAddr': '雲林縣口湖鄉湖東村四七號',
#    'hcho': '0',
#    's_d2': 10.0,
#    'odm': 'acelink.edimax',
#    's_d0': 15.0,
#    's_d1': 16.0,
#    's_h0': 91.0,
#    'gps_lat': 23.5872592,
#    's_t0': 30.5,
#    'adf_status': '0',
#    'fw_ver': 'v1.06',
#    'date': '2020-08-25',
#    'device_id': '08BEAC0A0502',
#    'gps_lon': 120.1840147,
#    's_g1': 0.0,
#    'time': '14:44:12',
#    'model': 'AI-1003WN',
#    'timestamp': '2020-08-25T14:44:12Z',
#    'c_d0': 6.95,
#    'c_d0_method': 'RFR/7/14.88'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '雲林縣縣立水燦林國小',
#    'SiteAddr': '雲林縣水林鄉水林村水林路六號',
#    'hcho': '0',
#    's_d2': 15.0,
#    'odm': 'acelink.edimax',
#    's_d0': 23.0,
#    's_d1': 24.0,
#    's_h0': 100.0,
#    'gps_lat': 23.57346296,
#    's_t0': 29.3,
#    'adf_status': '0',
#    'fw_ver': 'v1.06',
#    'date': '2020-08-25',
#    'device_id': '08BEAC0A0504',
#    'gps_lon': 120.2465736,
#    's_g1': 0.0,
#    'time': '14:42:40',
#    'model': 'AI-1003WN',
#    'timestamp': '2020-08-25T14:42:40Z',
#    'c_d0': 8.01,
#    'c_d0_method': 'RFR/7/11.84'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '臺南市市立茄拔國小',
#    'SiteAddr': '臺南市善化區嘉北里280號',
#    'hcho': '0',
#    's_d2': 10.0,
#    'odm': 'acelink.edimax',
#    's_d0': 16.0,
#    's_d1': 17.0,
#    's_h0': 100.0,
#    'gps_lat': 23.13865101,
#    's_t0': 28.5,
#    'adf_status': '0',
#    'fw_ver': 'v1.06',
#    'date': '2020-08-25',
#    'device_id': '08BEAC0A0508',
#    'gps_lon': 120.3244124,
#    's_g1': 0.0,
#    'time': '14:44:01',
#    'model': 'AI-1003WN',
#    'timestamp': '2020-08-25T14:44:01Z',
#    'c_d0': 10.09,
#    'c_d0_method': 'LinearR/30/18.62'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '嘉義縣縣立貴林國小',
#    'SiteAddr': '嘉義縣布袋鎮樹林里82號',
#    'hcho': '0',
#    's_d2': 12.0,
#    'odm': 'acelink.edimax',
#    's_d0': 22.0,
#    's_d1': 25.0,
#    's_h0': 100.0,
#    'gps_lat': 23.41953323,
#    's_t0': 27.6,
#    'adf_status': '0',
#    'fw_ver': 'v1.06',
#    'date': '2020-08-25',
#    'device_id': '08BEAC0A050A',
#    'gps_lon': 120.2139563,
#    's_g1': 0.0,
#    'time': '14:44:23',
#    'model': 'AI-1003WN',
#    'timestamp': '2020-08-25T14:44:23Z',
#    'c_d0': 9.77,
#    'c_d0_method': 'RFR/7/6.32'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '雲林縣縣立東仁國中',
#    'SiteAddr': '雲林縣古坑鄉朝陽村朝陽路二號',
#    'hcho': '0',
#    's_d2': 20.0,
#    'odm': 'acelink.edimax',
#    's_d0': 30.0,
#    's_d1': 32.0,
#    's_h0': 94.0,
#    'gps_lat': 23.71415087,
#    's_t0': 31.0,
#    'adf_status': '0',
#    'fw_ver': 'v1.06',
#    'date': '2020-08-25',
#    'device_id': '08BEAC0A050C',
#    'gps_lon': 120.4401474,
#    's_g1': 0.0,
#    'time': '14:40:00',
#    'model': 'AI-1003WN',
#    'timestamp': '2020-08-25T14:40:00Z',
#    'c_d0': 3.62,
#    'c_d0_method': 'SVR/7/10.68'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '雲林縣縣立崇德國中',
#    'SiteAddr': '雲林縣虎尾鎮廉使里五十號',
#    'hcho': '0',
#    's_d2': 15.0,
#    'odm': 'acelink.edimax',
#    's_d0': 23.0,
#    's_d1': 25.0,
#    's_h0': 100.0,
#    'gps_lat': 23.716679,
#    's_t0': 29.8,
#    'adf_status': '0',
#    'fw_ver': 'v1.06',
#    'date': '2020-08-25',
#    'device_id': '08BEAC0A0510',
#    'gps_lon': 120.4176137,
#    's_g1': 0.0,
#    'time': '14:42:56',
#    'model': 'AI-1003WN',
#    'timestamp': '2020-08-25T14:42:56Z',
#    'c_d0': 5.21,
#    'c_d0_method': 'SVR/7/12.98'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '臺南市市立大港國小',
#    'SiteAddr': '臺南市北區大港街146號',
#    'hcho': '0',
#    's_d2': 7.0,
#    'odm': 'acelink.edimax',
#    's_d0': 9.0,
#    's_d1': 12.0,
#    's_h0': 95.0,
#    'gps_lat': 23.0135245,
#    's_t0': 30.5,
#    'adf_status': '0',
#    'fw_ver': 'v1.06',
#    'date': '2020-08-25',
#    'device_id': '08BEAC0A0512',
#    'gps_lon': 120.1892436,
#    's_g1': 0.0,
#    'time': '14:39:34',
#    'model': 'AI-1003WN',
#    'timestamp': '2020-08-25T14:39:34Z',
#    'c_d0': 9.0,
#    'c_d0_method': 'SVR/14/3.47'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '雲林縣縣立建陽國小',
#    'SiteAddr': '雲林縣四湖鄉箔子村箔子寮三三三號',
#    'hcho': '0',
#    's_d2': 7.0,
#    'odm': 'acelink.edimax',
#    's_d0': 12.0,
#    's_d1': 14.0,
#    's_h0': 100.0,
#    'gps_lat': 23.6338569,
#    's_t0': 30.3,
#    'adf_status': '0',
#    'fw_ver': 'v1.06',
#    'date': '2020-08-25',
#    'device_id': '08BEAC0A0514',
#    'gps_lon': 120.1519047,
#    's_g1': 0.0,
#    'time': '14:44:21',
#    'model': 'AI-1003WN',
#    'timestamp': '2020-08-25T14:44:21Z',
#    'c_d0': 12.0,
#    'c_d0_method': 'RFR/7/20.98'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '臺南市市立和順國小',
#    'SiteAddr': '臺南市安南區安和路五段178巷5號',
#    'hcho': '0',
#    's_d2': 4.0,
#    'odm': 'acelink.edimax',
#    's_d0': 7.0,
#    's_d1': 7.0,
#    's_h0': 100.0,
#    'gps_lat': 23.066067,
#    's_t0': 29.1,
#    'adf_status': '0',
#    'fw_ver': 'v1.06',
#    'date': '2020-08-25',
#    'device_id': '08BEAC0A0518',
#    'gps_lon': 120.218457,
#    's_g1': 0.0,
#    'time': '14:43:00',
#    'model': 'AI-1003WN',
#    'timestamp': '2020-08-25T14:43:00Z',
#    'c_d0': 7.0,
#    'c_d0_method': 'SVR/14/9.15'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '臺南市市立層林國小',
#    'SiteAddr': '臺南市玉井區層林里115號',
#    'hcho': '0',
#    's_d2': 13.0,
#    'odm': 'acelink.edimax',
#    's_d0': 19.0,
#    's_d1': 20.0,
#    's_h0': 100.0,
#    'gps_lat': 23.07791538,
#    's_t0': 28.8,
#    'adf_status': '0',
#    'fw_ver': 'v1.06',
#    'date': '2020-08-25',
#    'device_id': '08BEAC0A051A',
#    'gps_lon': 120.4297107,
#    's_g1': 0.0,
#    'time': '14:40:27',
#    'model': 'AI-1003WN',
#    'timestamp': '2020-08-25T14:40:27Z',
#    'c_d0': 11.99,
#    'c_d0_method': 'GAM/14/23.93'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '臺南市市立安業國小',
#    'SiteAddr': '臺南市麻豆區安東里113號',
#    'hcho': '0',
#    's_d2': 5.0,
#    'odm': 'acelink.edimax',
#    's_d0': 9.0,
#    's_d1': 10.0,
#    's_h0': 100.0,
#    'gps_lat': 23.15990155,
#    's_t0': 27.7,
#    'adf_status': '0',
#    'fw_ver': 'v1.06',
#    'date': '2020-08-25',
#    'device_id': '08BEAC0A051C',
#    'gps_lon': 120.2462099,
#    's_g1': 0.0,
#    'time': '14:44:49',
#    'model': 'AI-1003WN',
#    'timestamp': '2020-08-25T14:44:49Z',
#    'c_d0': 9.0,
#    'c_d0_method': 'LinearR/30/17.78'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '嘉義縣縣立梅山國小',
#    'SiteAddr': '嘉義縣梅山鄉梅東村中山路28號之1',
#    'hcho': '0',
#    's_d2': 15.0,
#    'odm': 'acelink.edimax',
#    's_d0': 22.0,
#    's_d1': 23.0,
#    's_h0': 86.0,
#    'gps_lat': 23.58061985,
#    's_t0': 29.8,
#    'adf_status': '0',
#    'fw_ver': 'v1.06',
#    'date': '2020-08-25',
#    'device_id': '08BEAC0A0520',
#    'gps_lon': 120.5595461,
#    's_g1': 0.0,
#    'time': '14:43:31',
#    'model': 'AI-1003WN',
#    'timestamp': '2020-08-25T14:43:31Z',
#    'c_d0': 5.87,
#    'c_d0_method': 'SVR/7/14.68'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '雲林縣縣立褒忠國中',
#    'SiteAddr': '雲林縣褒忠鄉中勝路六二號',
#    'hcho': '0',
#    's_d2': 11.0,
#    'odm': 'acelink.edimax',
#    's_d0': 16.0,
#    's_d1': 17.0,
#    's_h0': 100.0,
#    'gps_lat': 23.69969844,
#    's_t0': 30.3,
#    'adf_status': '0',
#    'fw_ver': 'v1.06',
#    'date': '2020-08-25',
#    'device_id': '08BEAC0A0522',
#    'gps_lon': 120.3110861,
#    's_g1': 0.0,
#    'time': '14:42:54',
#    'model': 'AI-1003WN',
#    'timestamp': '2020-08-25T14:42:54Z',
#    'c_d0': 9.01,
#    'c_d0_method': 'SVR/7/23.85'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '08BEAC0A0524',
#    'SiteAddr': 'N/A',
#    'hcho': '0',
#    's_d2': 12.0,
#    'odm': 'acelink.edimax',
#    's_d0': 20.0,
#    's_d1': 21.0,
#    's_h0': 77.0,
#    'gps_lat': 24.109845,
#    's_t0': 31.6,
#    'adf_status': '0',
#    'fw_ver': 'v1.06',
#    'date': '2020-08-25',
#    'device_id': '08BEAC0A0524',
#    'gps_lon': 120.638621,
#    's_g1': 0.0,
#    'time': '14:39:59',
#    'model': 'AI-1003WN',
#    'timestamp': '2020-08-25T14:39:59Z',
#    'c_d0': 13.41,
#    'c_d0_method': 'GAM/14/4.69'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '嘉義縣縣立嘉新國中',
#    'SiteAddr': '嘉義縣太保市中山路一段586巷7號',
#    'hcho': '0',
#    's_d2': 15.0,
#    'odm': 'acelink.edimax',
#    's_d0': 23.0,
#    's_d1': 24.0,
#    's_h0': 87.0,
#    'gps_lat': 23.500389,
#    's_t0': 30.5,
#    'adf_status': '0',
#    'fw_ver': 'v1.06',
#    'date': '2020-08-25',
#    'device_id': '08BEAC0A0526',
#    'gps_lon': 120.378001,
#    's_g1': 0.0,
#    'time': '14:44:15',
#    'model': 'AI-1003WN',
#    'timestamp': '2020-08-25T14:44:15Z',
#    'c_d0': 9.68,
#    'c_d0_method': 'RFR/7/7.65'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '臺南市市立麻豆國中',
#    'SiteAddr': '臺南市麻豆區南勢里36號',
#    'hcho': '0',
#    's_d2': 7.0,
#    'odm': 'acelink.edimax',
#    's_d0': 12.0,
#    's_d1': 12.0,
#    's_h0': 94.0,
#    'gps_lat': 23.1828117371,
#    's_t0': 28.8,
#    'adf_status': '0',
#    'fw_ver': 'v1.06',
#    'date': '2020-08-25',
#    'device_id': '08BEAC0A052A',
#    'gps_lon': 120.259864807,
#    's_g1': 0.0,
#    'time': '14:43:56',
#    'model': 'AI-1003WN',
#    'timestamp': '2020-08-25T14:43:56Z',
#    'c_d0': 12.0,
#    'c_d0_method': 'LinearR/30/14.89'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '嘉義縣縣立梅北國小',
#    'SiteAddr': '嘉義縣梅山鄉梅北村民生街1號',
#    'hcho': '0',
#    's_d2': 13.0,
#    'odm': 'acelink.edimax',
#    's_d0': 21.0,
#    's_d1': 22.0,
#    's_h0': 88.0,
#    'gps_lat': 23.5873308376,
#    's_t0': 30.2,
#    'adf_status': '0',
#    'fw_ver': 'v1.06',
#    'date': '2020-08-25',
#    'device_id': '08BEAC0A052C',
#    'gps_lon': 120.552114509,
#    's_g1': 0.0,
#    'time': '14:43:52',
#    'model': 'AI-1003WN',
#    'timestamp': '2020-08-25T14:43:52Z',
#    'c_d0': 6.54,
#    'c_d0_method': 'SVR/7/13.88'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '雲林縣縣立新生國小',
#    'SiteAddr': '雲林縣元長鄉瓦搖村新生路十一號',
#    'hcho': '0',
#    's_d2': 25.0,
#    'odm': 'acelink.edimax',
#    's_d0': 33.0,
#    's_d1': 42.0,
#    's_h0': 100.0,
#    'gps_lat': 23.63780915,
#    's_t0': 29.0,
#    'adf_status': '0',
#    'fw_ver': 'v1.06',
#    'date': '2020-08-25',
#    'device_id': '08BEAC0A0530',
#    'gps_lon': 120.3590977,
#    's_g1': 0.0,
#    'time': '14:40:32',
#    'model': 'AI-1003WN',
#    'timestamp': '2020-08-25T14:40:32Z',
#    'c_d0': 5.95,
#    'c_d0_method': 'SVR/7/20.65'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '臺南市市立北勢國小',
#    'SiteAddr': '臺南市麻豆區北勢里15號',
#    'hcho': '0',
#    's_d2': 9.0,
#    'odm': 'acelink.edimax',
#    's_d0': 14.0,
#    's_d1': 14.0,
#    's_h0': 100.0,
#    'gps_lat': 23.20546338,
#    's_t0': 29.2,
#    'adf_status': '0',
#    'fw_ver': 'v1.06',
#    'date': '2020-08-25',
#    'device_id': '08BEAC0A0532',
#    'gps_lon': 120.2402751,
#    's_g1': 0.0,
#    'time': '14:41:37',
#    'model': 'AI-1003WN',
#    'timestamp': '2020-08-25T14:41:37Z',
#    'c_d0': 9.46,
#    'c_d0_method': 'LinearR/30/13.65'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '嘉義縣縣立柳林國小',
#    'SiteAddr': '嘉義縣水上鄉柳林村92號',
#    'hcho': '0',
#    's_d2': 12.0,
#    'odm': 'acelink.edimax',
#    's_d0': 19.0,
#    's_d1': 20.0,
#    's_h0': 100.0,
#    'gps_lat': 23.43568913,
#    's_t0': 30.1,
#    'adf_status': '0',
#    'fw_ver': 'v1.06',
#    'date': '2020-08-25',
#    'device_id': '08BEAC0A0534',
#    'gps_lon': 120.415497,
#    's_g1': 0.0,
#    'time': '14:40:37',
#    'model': 'AI-1003WN',
#    'timestamp': '2020-08-25T14:40:37Z',
#    'c_d0': 8.07,
#    'c_d0_method': 'RFR/7/4.0'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '臺南市市立麻豆國小',
#    'SiteAddr': '臺南市麻豆區東角里文昌路18號',
#    'hcho': '0',
#    's_d2': 9.0,
#    'odm': 'acelink.edimax',
#    's_d0': 14.0,
#    's_d1': 15.0,
#    's_h0': 100.0,
#    'gps_lat': 23.18594305,
#    's_t0': 29.0,
#    'adf_status': '0',
#    'fw_ver': 'v1.06',
#    'date': '2020-08-25',
#    'device_id': '08BEAC0A0536',
#    'gps_lon': 120.2534818,
#    's_g1': 0.0,
#    'time': '14:42:20',
#    'model': 'AI-1003WN',
#    'timestamp': '2020-08-25T14:42:20Z',
#    'c_d0': 9.39,
#    'c_d0_method': 'LinearR/30/14.84'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '臺南市市立新東國中',
#    'SiteAddr': '臺南市新營區民治東路30號',
#    'hcho': '0',
#    's_d2': 7.0,
#    'odm': 'acelink.edimax',
#    's_d0': 11.0,
#    's_d1': 12.0,
#    's_h0': 74.0,
#    'gps_lat': 23.31190196,
#    's_t0': 31.1,
#    'adf_status': '0',
#    'fw_ver': 'v1.06',
#    'date': '2020-08-25',
#    'device_id': '08BEAC0A0538',
#    'gps_lon': 120.324114,
#    's_g1': 0.0,
#    'time': '14:40:42',
#    'model': 'AI-1003WN',
#    'timestamp': '2020-08-25T14:40:42Z',
#    'c_d0': 11.0,
#    'c_d0_method': 'LinearR/30/0.98'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '臺南市市立學甲國中',
#    'SiteAddr': '臺南市學甲區華宗路540號',
#    'hcho': '0',
#    's_d2': 12.0,
#    'odm': 'acelink.edimax',
#    's_d0': 21.0,
#    's_d1': 22.0,
#    's_h0': 100.0,
#    'gps_lat': 23.2371735,
#    's_t0': 30.1,
#    'adf_status': '0',
#    'fw_ver': 'v1.06',
#    'date': '2020-08-25',
#    'device_id': '08BEAC0A053A',
#    'gps_lon': 120.1839039,
#    's_g1': 0.0,
#    'time': '14:42:20',
#    'model': 'AI-1003WN',
#    'timestamp': '2020-08-25T14:42:20Z',
#    'c_d0': 12.97,
#    'c_d0_method': 'LinearR/30/15.6'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '嘉義縣縣立成功國小',
#    'SiteAddr': '嘉義縣水上鄉三界村153號',
#    'hcho': '0',
#    's_d2': 13.0,
#    'odm': 'acelink.edimax',
#    's_d0': 19.0,
#    's_d1': 21.0,
#    's_h0': 85.0,
#    'gps_lat': 23.432459,
#    's_t0': 30.8,
#    'adf_status': '0',
#    'fw_ver': 'v1.06',
#    'date': '2020-08-25',
#    'device_id': '08BEAC0A053E',
#    'gps_lon': 120.475488,
#    's_g1': 0.0,
#    'time': '14:41:59',
#    'model': 'AI-1003WN',
#    'timestamp': '2020-08-25T14:41:59Z',
#    'c_d0': 8.07,
#    'c_d0_method': 'RFR/7/4.89'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '臺南市市立西門實驗小學',
#    'SiteAddr': '臺南市安平區安北路180號',
#    'hcho': '0',
#    's_d2': 5.0,
#    'odm': 'acelink.edimax',
#    's_d0': 9.0,
#    's_d1': 11.0,
#    's_h0': 91.0,
#    'gps_lat': 23.0027769,
#    's_t0': 31.6,
#    'adf_status': '0',
#    'fw_ver': 'v1.06',
#    'date': '2020-08-25',
#    'device_id': '08BEAC0A0540',
#    'gps_lon': 120.1592178,
#    's_g1': 0.0,
#    'time': '14:44:41',
#    'model': 'AI-1003WN',
#    'timestamp': '2020-08-25T14:44:41Z',
#    'c_d0': 9.0,
#    'c_d0_method': 'SVR/14/4.9'},
#   {'gps_num': 9.0,
#    'gps_fix': 1.0,
#    'gps_alt': 2.0,
#    'app': 'AirBox',
#    'SiteName': '嘉義縣縣立鹿草國中',
#    'SiteAddr': '嘉義縣鹿草鄉鹿草村439號',
#    'hcho': '0',
#    's_d2': 0.0,
#    'odm': 'acelink.edimax',
#    's_d0': 1.0,
#    's_d1': 1.0,
#    's_h0': 100.0,
#    'gps_lat': 23.40988426,
#    's_t0': 29.0,
#    'adf_status': '0',
#    'fw_ver': 'v1.06',
#    'date': '2020-08-25',
#    'device_id': '08BEAC0A0542',
#    'gps_lon': 120.3128694,
#    's_g1': 0.0,
#    'time': '14:43:11',
#    'model': 'AI-1003WN',
#    'timestamp': '2020-08-25T14:43:11Z',
#    'c_d0': 1.0,
#    'c_d0_method': 'RFR/7/9.17'},
#   ...],
#  'descriptions': {'URL': 'https://pm25.lass-net.org/data/description.json',
#   'c_d0_method': 'method/days/distance(km)',
#   'c_d0': 'calibration PM2.5 (ug/m3)'},
#  'version': '2020-08-25T14:46:41Z'}

# %%
data_list=data['feeds']
##一個測站的數值
data_list[10]
# Out:
# {'gps_num': 9.0,
#  'gps_fix': 1.0,
#  'gps_alt': 2.0,
#  'app': 'AirBox',
#  'SiteName': '萬華-2',
#  'SiteAddr': 'Wanhua',
#  's_d0': 27.0,
#  's_d1': 29.0,
#  's_h0': 100.0,
#  'area': 'taipei',
#  'gps_lat': 25.046,
#  's_t0': 29.86,
#  'gps_lon': 121.508,
#  'date': '2020-08-25',
#  'device_id': '08BEAC028690',
#  'name': '手動站：萬華站-2（690)',
#  'time': '14:39:26',
#  's_d2': 18.0,
#  'timestamp': '2020-08-25T14:39:26Z',
#  'c_d0': 15.82,
#  'c_d0_method': 'SVR/30/0.11'}

# %%
##存資料的DataFrame
data_taipei=pd.DataFrame(columns=['device_id','PM2.5','lat','lon'])
## i存沒有區域資訊的站有幾個
i=0
for i in range(len(data_list)):
##抓出在台北的測站
    try:
        if data_list[i]['area']=='taipei':
            data_taipei.loc[i,'device_id']=data_list[i]['device_id']
            data_taipei.loc[i,'PM2.5']=data_list[i]['s_d0']
            data_taipei.loc[i,'lat']=data_list[i]['gps_lat']
            data_taipei.loc[i,'lon']=data_list[i]['gps_lon']
        
    except:
        i=i+1
print(i)
data_taipei.reset_index(inplace=True)
data_taipei
# Out:
# 3049
#      index     device_id PM2.5      lat      lon
# 0       10  08BEAC028690    27   25.046  121.508
# 1       46  08BEAC028780    16   25.119  121.469
# 2       53  08BEAC0287F6    23   25.038  121.546
# 3      138  08BEAC028A20    16  24.8211  121.103
# 4      152  08BEAC028A4C    22  25.0417  121.544
# ..     ...           ...   ...      ...      ...
# 210   3036  74DA38F7C60C    25   25.056  121.562
# 211   3037  74DA38F7C60E    26   25.029  121.532
# 212   3038  74DA38F7C610    25   25.063  121.564
# 213   3040  74DA38F7C616    26   25.031  121.563
# 214   3041  74DA38F7C622    25   25.038  121.586
#
# [215 rows x 5 columns]

# %%
#畫一張可以知道各站點位置的地圖 還有pm2.5的值
m = folium.Map( location=[25.04282, 121.538],zoom_start=13,tiles='OpenStreetMap')

tooltip = 'Click me!'
for i in range(len(data_taipei)):
    df = pd.DataFrame(data=[[data_taipei['device_id'][i],data_taipei['PM2.5'][i]]], columns=['ID','PM2.5'])
    html = df.to_html(classes='table table-striped table-hover table-condensed table-responsive')
    popup = folium.Popup(html)
    folium.Marker([data_taipei.lat[i],data_taipei.lon[i]], popup=popup, tooltip=tooltip,icon=folium.Icon(color='red')).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
##拿測站pm2.5資料畫熱點圖
from folium import plugins
from folium.plugins import HeatMap
##生成資料
PM=data_taipei.apply(lambda x: [x['lat'] ,x['lon'],x['PM2.5']], axis=1)

m = folium.Map([25.04282, 121.538], tiles='OpenStreetMap', zoom_start=13)

HeatMap(PM).add_to(folium.FeatureGroup(name='Heat Map').add_to(m))
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
